# %%
# --- ANÁLISIS DE ESTRUCTURA DEL FORMULARIO DE SEGURO VEHICULAR ---

import pandas as pd
import os
os.getcwd()


# Cargar el archivo Excel (ajusta el nombre si difiere)
df = pd.read_excel("data/SEGUROS (respuestas).xlsx")

# Mostrar información básica
print("🔹 Dimensiones del dataset:")
print(df.shape)

print("\n🔹 Primeras filas:")
display(df.head())

print("\n🔹 Tipos de datos por columna:")
print(df.dtypes)

print("\n🔹 Porcentaje de valores nulos por variable:")
print(df.isnull().mean() * 100)

print("\n🔹 Resumen estadístico (solo variables numéricas):")
display(df.describe())
# Out:
# 🔹 Dimensiones del dataset:
# (82, 15)
#
# 🔹 Primeras filas:
#            Marca temporal 1. Edad:   2. Sexo:   \
# 0 2025-10-09 18:06:56.749        36   Femenino
# 1 2025-10-09 18:19:19.088        24  Masculino
# 2 2025-10-09 18:22:43.131        30   Femenino
# 3 2025-10-09 18:27:13.314        34  Masculino
# 4 2025-10-09 18:28:32.850        30  Masculino
#
#            3. Ocupación principal:   \
# 0                        Empleado/a
# 1  Independiente / Negocios propios
# 2                        Empleado/a
# 3                        Estudiante
# 4                        Empleado/a
#
#                                4. ¿Cómo nos conoció?  \
# 0                 Recomendación de un familiar/amigo
# 1                 Recomendación de un familiar/amigo
# 2                 Recomendación de un familiar/amigo
# 3  Redes sociales (Facebook, Instagram, TikTok, e...
# 4  Redes sociales (Facebook, Instagram, TikTok, e...
#
#   5. ¿Qué tan fácil fue contactarnos?  \
# 0                               Fácil
# 1                             Difícil
# 2                               Fácil
# 3                             Regular
# 4                           Muy fácil
#
#                      6. Tipo de vehículo que posee:   \
# 0                                          Camioneta
# 1                                          Camioneta
# 2                                               Auto
# 3  Vehículo de trabajo (ej. taxi, transporte, carga)
# 4                                               Moto
#
#          7. Uso principal del vehículo    \
# 0  Uso laboral (trabajo propio, negocio)
# 1                  Uso personal/familiar
# 2                  Uso personal/familiar
# 3  Uso laboral (trabajo propio, negocio)
# 4  Uso laboral (trabajo propio, negocio)
#
#   8. ¿Con qué frecuencia utiliza su vehículo?    \
# 0                                Todos los días
# 1                       Varias veces por semana
# 2              Fines de semana / ocasionalmente
# 3                                Todos los días
# 4                                Todos los días
#
#   9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción)    \
# 0  Daños a terceros, Asistencia mecánica, Taller ...
# 1  Daños a terceros, Robo total del vehículo, Cob...
# 2              Robo total del vehículo, Daños propio
# 3                                       Daños propio
# 4  Daños a terceros, Robo total del vehículo, Dañ...
#
#   10. ¿Qué tan importante es para usted contar con un seguro actualmente?  \
# 0                                    Poco importante
# 1                                     Muy importante
# 2                                    Poco importante
# 3                                         Importante
# 4                                     Muy importante
#
#   11. ¿Cuál es el principal motivo por el que contrataría un seguro?  \
# 0                    Protección de bienes materiales
# 1                    Protección de bienes materiales
# 2                 Exigencia laboral / de institución
# 3         Tranquilidad y seguridad personal/familiar
# 4         Tranquilidad y seguridad personal/familiar
#
#   12. ¿Ha solicitado información sobre pólizas anteriormente?  \
# 0                                                 No
# 1                                                 Sí
# 2                                                 No
# 3                                                 No
# 4                                                 Sí
#
#   13. ¿Terminó comprando una póliza con nosotros?  \
# 0                     No, pero estoy interesado/a
# 1                                              Sí
# 2                     No, y no estoy interesado/a
# 3                     No, pero estoy interesado/a
# 4                                              Sí
#
#   14. ¿Cuál fue el principal motivo para no adquirir la póliza?
# 0                                     Precio elevado
# 1                                                NaN
# 2  En general he tenido muchos problemas con aseg...
# 3                         No era el momento adecuado
# 4                                     Precio elevado
# 🔹 Tipos de datos por columna:
# Marca temporal                                                                                  datetime64[ns]
# 1. Edad:                                                                                                object
# 2. Sexo:                                                                                                object
# 3. Ocupación principal:                                                                                 object
# 4. ¿Cómo nos conoció?                                                                                   object
# 5. ¿Qué tan fácil fue contactarnos?                                                                     object
# 6. Tipo de vehículo que posee:                                                                          object
# 7. Uso principal del vehículo                                                                           object
# 8. ¿Con qué frecuencia utiliza su vehículo?                                                             object
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción)              object
# 10. ¿Qué tan importante es para usted contar con un seguro actualmente?                                 object
# 11. ¿Cuál es el principal motivo por el que contrataría un seguro?                                      object
# 12. ¿Ha solicitado información sobre pólizas anteriormente?                                             object
# 13. ¿Terminó comprando una póliza con nosotros?                                                         object
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza?                                           object
# dtype: object
#
# 🔹 Porcentaje de valores nulos por variable:
# Marca temporal                                                                                   0.000000
# 1. Edad:                                                                                         1.219512
# 2. Sexo:                                                                                         4.878049
# 3. Ocupación principal:                                                                         24.390244
# 4. ¿Cómo nos conoció?                                                                            4.878049
# 5. ¿Qué tan fácil fue contactarnos?                                                              1.219512
# 6. Tipo de vehículo que posee:                                                                   1.219512
# 7. Uso principal del vehículo                                                                    1.219512
# 8. ¿Con qué frecuencia utiliza su vehículo?                                                      1.219512
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción)       2.439024
# 10. ¿Qué tan importante es para usted contar con un seguro actualmente?                          2.439024
# 11. ¿Cuál es el principal motivo por el que contrataría un seguro?                               1.219512
# 12. ¿Ha solicitado información sobre pólizas anteriormente?                                      1.219512
# 13. ¿Terminó comprando una póliza con nosotros?                                                  6.097561
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza?                                   19.512195
# dtype: float64
#
# 🔹 Resumen estadístico (solo variables numéricas):
#                       Marca temporal
# count                             82
# mean   2025-10-16 09:09:36.667000064
# min       2025-10-09 18:06:56.749000
# 25%    2025-10-09 20:17:06.287000064
# 50%    2025-10-12 21:12:13.509499904
# 75%    2025-10-23 15:10:11.986249984
# max       2025-10-24 09:00:48.764000

# %%
# --- VALIDACIÓN Y CONFIABILIDAD DEL CUESTIONARIO ---

import pandas as pd
import numpy as np

# Reutilizar el dataframe existente
# Si lo reiniciaste, vuelve a cargar:
# df = pd.read_excel("SEGUROS (respuestas).xlsx")

# Copiamos solo las columnas de escala Likert o similares
escala = df[[
    '5. ¿Qué tan fácil fue contactarnos?',
    '10. ¿Qué tan importante es para usted contar con un seguro actualmente?'
]].copy()

# Codificación ordinal
map_facilidad = {
    'Muy difícil': 1,
    'Difícil': 2,
    'Regular': 3,
    'Fácil': 4,
    'Muy fácil': 5
}

map_importancia = {
    'Nada importante': 1,
    'Poco importante': 2,
    'Regular': 3,
    'Importante': 4,
    'Muy importante': 5
}

escala['facilidad_contacto'] = escala.iloc[:, 0].map(map_facilidad)
escala['importancia_seguro'] = escala.iloc[:, 1].map(map_importancia)

# Eliminar columnas originales
escala = escala.drop(columns=escala.columns[:2])

# Calcular Alfa de Cronbach
def cronbach_alpha(df_num):
    df_num = df_num.dropna()
    k = df_num.shape[1]
    variancias = df_num.var(axis=0, ddof=1)
    var_total = df_num.sum(axis=1).var(ddof=1)
    return (k / (k - 1)) * (1 - (variancias.sum() / var_total))

alpha = cronbach_alpha(escala)
print(f"🔹 Alfa de Cronbach: {alpha:.3f}")

# Correlación entre ítems
print("\n🔹 Matriz de correlaciones:")
display(escala.corr())
# Out:
# 🔹 Alfa de Cronbach: 0.520
#
# 🔹 Matriz de correlaciones:
#                     facilidad_contacto  importancia_seguro
# facilidad_contacto             1.00000             0.37463
# importancia_seguro             0.37463             1.00000

# %%
# ------------------------
#  CODIFICACIÓN CORRECTA (SIN NORMALIZAR)
# ------------------------
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Cargar archivo (ajusta el nombre si es distinto)
df = pd.read_excel("data/SEGUROS (respuestas).xlsx")

# Limpieza básica de encabezados
df = df.drop(columns=["Marca temporal"], errors="ignore")
df.columns = [col.strip().replace('\n',' ').replace('\r','') for col in df.columns]

# Mantener edad como numérica (no la transformamos a etiquetas)
col_edad = [c for c in df.columns if "Edad" in c][0]
df[col_edad] = pd.to_numeric(df[col_edad], errors="coerce")
# (Opcional) rellenar NaN en edad con la media — puedes cambiar esto si prefieres otra estrategia
df[col_edad] = df[col_edad].fillna(int(df[col_edad].mean()))

# ------------------------
# Mapear respuestas ordinales (P5 y P10) a enteros 1..5
# ------------------------
map_facilidad = {
    "Muy difícil": 1,
    "Difícil": 2,
    "Regular": 3,
    "Fácil": 4,
    "Muy fácil": 5
}
col_p5 = "5. ¿Qué tan fácil fue contactarnos?"
df[col_p5] = df[col_p5].map(map_facilidad)

map_importancia = {
    "Nada importante": 1,
    "Poco importante": 2,
    "Regular": 3,
    "Importante": 4,
    "Muy importante": 5,
    # por si hay variantes:
    "Extremadamente importante": 5
}
col_p10 = "10. ¿Qué tan importante es para usted contar con un seguro actualmente?"
df[col_p10] = df[col_p10].map(map_importancia)

# Si hubo valores no mapeados (NaN) en P5/P10, rellenar con la moda (valor más frecuente)
if df[col_p5].isna().any():
    moda_p5 = int(df[col_p5].mode().iloc[0])
    df[col_p5] = df[col_p5].fillna(moda_p5)
if df[col_p10].isna().any():
    moda_p10 = int(df[col_p10].mode().iloc[0])
    df[col_p10] = df[col_p10].fillna(moda_p10)

# ------------------------
# Selección múltiple: P9 , P13 y P14 -> dummies binarias (0/1)
# ------------------------
cols_multi = [
    "9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción)",
    "14. ¿Cuál fue el principal motivo para no adquirir la póliza?"
]

multi_dfs = []
for col in cols_multi:
    if col in df.columns:
        # separación por coma, eliminar espacios extra
        temp = df[col].fillna("").astype(str).str.split(',')
        # crear dummies manualmente para controlar nombres
        # primero obtener todas las opciones presentes
        options = set()
        for entry in temp:
            for opt in entry:
                opt = opt.strip()
                if opt != "" and opt.lower() != "no especifica":
                    options.add(opt)
        options = sorted(options)
        # crear columnas binarias para cada opción
        temp_df = pd.DataFrame(0, index=df.index, columns=[f"{col} - {opt}" for opt in options])
        for i, entry in enumerate(temp):
            for opt in entry:
                opt = opt.strip()
                if opt != "" and opt in options:
                    temp_df.at[i, f"{col} - {opt}"] = 1
        multi_dfs.append(temp_df)
        # eliminar columna original
        df = df.drop(columns=[col], errors="ignore")

# anexar dummies (si existen)
if multi_dfs:
    df = pd.concat([df] + multi_dfs, axis=1)

# ------------------------
# Codificar restantes variables categóricas con LabelEncoder (enteros)
# ------------------------
le = LabelEncoder()
for col in df.columns:
    if col == col_edad:
        continue  # no tocar edad
    # si ya es numérico (int/float) y tiene solo 0/1 => dejar como está
    if pd.api.types.is_numeric_dtype(df[col]) and set(df[col].dropna().unique()).issubset({0,1}):
        df[col] = df[col].astype(int)
        continue
    # si es numérico pero no 0/1 (por ejemplo target codificada como texto), convertir a int si procede
    if pd.api.types.is_numeric_dtype(df[col]) and not pd.api.types.is_integer_dtype(df[col]):
        # si son floats producto de lecturas, convertir a int cuando sean enteros
        if all((df[col].dropna() % 1 == 0)):
            df[col] = df[col].astype(int)
            continue
    # si es tipo object -> aplicar LabelEncoder y convertir a entero
    if df[col].dtype == 'object' or pd.api.types.is_string_dtype(df[col]):
        df[col] = df[col].fillna("No especifica")
        df[col] = le.fit_transform(df[col].astype(str)).astype(int)

# ------------------------
# Verificación: asegurar que las columnas categóricas tienen dtype int (sin decimales)
# ------------------------
for col in df.columns:
    if col == col_edad:
        print(f"{col}: dtype={df[col].dtype} (edad, no integer forced)")
    else:
        # forzar int
        try:
            df[col] = df[col].astype(int)
        except Exception:
            pass
        print(f"{col}: dtype={df[col].dtype}, unique_vals_sample={df[col].unique()[:5]}")

# ------------------------
# Guardar CSV sin normalizar
# ------------------------
from pathlib import Path

OUTPUT_DIR = Path("data")
OUTPUT_DIR.mkdir(exist_ok=True)

outname = OUTPUT_DIR / "seguros_codificado.csv"
df.to_csv(outname, index=False, encoding="utf-8-sig")

print(f"✅ Archivo guardado en: {outname}")
# Out:
# 1. Edad:: dtype=float64 (edad, no integer forced)
# 2. Sexo:: dtype=int64, unique_vals_sample=[0 1 2]
# 3. Ocupación principal:: dtype=int64, unique_vals_sample=[0 2 1 3]
# 4. ¿Cómo nos conoció?: dtype=int64, unique_vals_sample=[2 3 1 0]
# 5. ¿Qué tan fácil fue contactarnos?: dtype=int64, unique_vals_sample=[4 2 3 5]
# 6. Tipo de vehículo que posee:: dtype=int64, unique_vals_sample=[1 0 6 2 3]
# 7. Uso principal del vehículo: dtype=int64, unique_vals_sample=[5 6 4 2 1]
# 8. ¿Con qué frecuencia utiliza su vehículo?: dtype=int64, unique_vals_sample=[3 4 0 1 2]
# 10. ¿Qué tan importante es para usted contar con un seguro actualmente?: dtype=int64, unique_vals_sample=[2 5 4 1]
# 11. ¿Cuál es el principal motivo por el que contrataría un seguro?: dtype=int64, unique_vals_sample=[2 0 3 7 6]
# 12. ¿Ha solicitado información sobre pólizas anteriormente?: dtype=int64, unique_vals_sample=[0 2 1]
# 13. ¿Terminó comprando una póliza con nosotros?: dtype=int64, unique_vals_sample=[1 3 2 0]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Abastecimiento de combustible: dtype=int64, unique_vals_sample=[0 1]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Asistencia mecánica: dtype=int64, unique_vals_sample=[1 0]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Cobertura contra desastres naturales: dtype=int64, unique_vals_sample=[0 1]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Daños a terceros: dtype=int64, unique_vals_sample=[1 0]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Daños propio: dtype=int64, unique_vals_sample=[0 1]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - No tengo auto: dtype=int64, unique_vals_sample=[0 1]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Robo total del vehículo: dtype=int64, unique_vals_sample=[0 1]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Robos al paso: dtype=int64, unique_vals_sample=[0 1]
# 9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Taller móvil: dtype=int64, unique_vals_sample=[1 0]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Aún no cuento con un auto: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - En general he tenido muchos problemas con aseguradoras: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Falta de confianza en la aseguradora: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Mi auto es muy antiguo y no lo aseguran: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Mi seguro vence en un mes y ahí lo adquiriría aqui: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No entendí bien las condiciones: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No era el momento adecuado: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Poco uso vehículo: dtype=int64, unique_vals_sample=[0 1]
# 14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Precio elevado: dtype=int64, unique_vals_sample=[1 0]
# ✅ Archivo guardado en: data\seguros_codificado.csv

# %%
from sklearn.preprocessing import MinMaxScaler
from pathlib import Path

scaler = MinMaxScaler()

# mismas columnas que en tu código
cols_to_scale = [c for c in df.columns if c != col_edad]

# mismo escalado (in-place sobre df)
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# mismo archivo, solo cambia la forma de guardado
OUTPUT_DIR = Path("data")
OUTPUT_DIR.mkdir(exist_ok=True)

outname = OUTPUT_DIR / "seguros_codificado_normalizado.csv"
df.to_csv(outname, index=False, encoding="utf-8-sig")

print(f"✅ Archivo guardado en: {outname}")
# Out:
# ✅ Archivo guardado en: data\seguros_codificado_normalizado.csv

# %%
# ==========================================
# 🧠 GENERAR DATA SINTÉTICA BASADA EN EL CSV REAL
# ==========================================
import pandas as pd
import numpy as np
from faker import Faker
from pathlib import Path

# Cargar el dataset real codificado
df_real = pd.read_csv("seguros_codificado.csv")

# Semilla para reproducibilidad
np.random.seed(42)

# Crear dataset sintético con mismas columnas y 82 registros
n_rows = 82
cols = df_real.columns
df_sintetico = pd.DataFrame(columns=cols)

# Generador Faker (por si hay variables tipo edad o numéricas)
fake = Faker()

# Para cada columna, generamos datos con una distribución similar
for col in df_real.columns:
    serie = df_real[col]

    if pd.api.types.is_numeric_dtype(serie):
        # Si es numérica entera (codificación o binaria)
        if all(serie.dropna().astype(float).apply(float.is_integer)):
            valores = serie.dropna().astype(int).values
            # Generar con la misma frecuencia aproximada
            probs = np.unique(valores, return_counts=True)[1] / len(valores)
            opciones = np.unique(valores)
            df_sintetico[col] = np.random.choice(opciones, size=n_rows, p=probs)
        else:
            # Si es numérica continua (por ejemplo edad)
            mu, sigma = serie.mean(), serie.std()
            df_sintetico[col] = np.abs(
                np.random.normal(mu, sigma, n_rows)
            ).round(0).astype(int)
    else:
        # Si por alguna razón hay columnas tipo texto (no debería)
        valores = serie.dropna().unique()
        df_sintetico[col] = np.random.choice(valores, size=n_rows)

# Aseguramos que los tipos sean correctos (int)
for col in df_sintetico.columns:
    try:
        df_sintetico[col] = df_sintetico[col].astype(int)
    except Exception:
        pass

# ==========================================
# 💾 GUARDAR CSV SINTÉTICO (VS CODE)
# ==========================================
OUTPUT_DIR = Path("data")
OUTPUT_DIR.mkdir(exist_ok=True)

nombre_salida = OUTPUT_DIR / "seguros_sintetico.csv"
df_sintetico.to_csv(nombre_salida, index=False, encoding="utf-8-sig")

print("✅ Data sintética generada correctamente:")
display(df_sintetico.head())
print(f"📁 Archivo guardado en: {nombre_salida}")
# Out:
# ✅ Data sintética generada correctamente:
#    1. Edad:  2. Sexo:  3. Ocupación principal:  4. ¿Cómo nos conoció?  \
# 0        34         0                        0                      2
# 1        56         0                        3                      3
# 2        43         0                        0                      3
# 3        39         0                        0                      2
# 4        30         1                        0                      2
#
#    5. ¿Qué tan fácil fue contactarnos?  6. Tipo de vehículo que posee:  \
# 0                                    4                               0
# 1                                    3                               3
# 2                                    3                               3
# 3                                    4                               0
# 4                                    3                               1
#
#    7. Uso principal del vehículo  8. ¿Con qué frecuencia utiliza su vehículo?  \
# 0                              6                                            4
# 1                              6                                            4
# 2                              6                                            1
# 3                              6                                            4
# 4                              6                                            3
#
#    10. ¿Qué tan importante es para usted contar con un seguro actualmente?  \
# 0                                                  4
# 1                                                  4
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    11. ¿Cuál es el principal motivo por el que contrataría un seguro?  ...  \
# 0                                                  3                   ...
# 1                                                  3                   ...
# 2                                                  3                   ...
# 3                                                  3                   ...
# 4                                                  3                   ...
#
#    9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Taller móvil  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Aún no cuento con un auto  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - En general he tenido muchos problemas con aseguradoras  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Falta de confianza en la aseguradora  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Mi auto es muy antiguo y no lo aseguran  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Mi seguro vence en un mes y ahí lo adquiriría aqui  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No entendí bien las condiciones  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No era el momento adecuado  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Poco uso vehículo  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Precio elevado
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
# [5 rows x 30 columns]
# 📁 Archivo guardado en: data\seguros_sintetico.csv

# %%
# ============================================================
# 🧠 GENERAR DATA MIXTA BASADA EN EL CSV REAL Y CSV SINTÉTICO
# ============================================================

import pandas as pd
from pathlib import Path

# Cargar los archivos (locales)
df_real = pd.read_csv("data/seguros_codificado.csv")
df_sint = pd.read_csv("data/seguros_sintetico.csv")

# Asegurar mismas columnas
common_cols = list(set(df_real.columns) & set(df_sint.columns))
df_real = df_real[common_cols]
df_sint = df_sint[common_cols]

# Igualar cantidad de filas
n = min(len(df_real), len(df_sint))
n_half = n // 2

# Tomar 50% de cada dataset
df_mix = pd.concat(
    [
        df_real.sample(n=n_half, random_state=42),
        df_sint.sample(n=n_half, random_state=42)
    ],
    ignore_index=True
)

# Mezclar filas
df_mix = df_mix.sample(frac=1, random_state=42).reset_index(drop=True)

# ============================================================
# 💾 GUARDAR CSV MIXTO (VS CODE)
# ============================================================

OUTPUT_DIR = Path("data")
OUTPUT_DIR.mkdir(exist_ok=True)

output_path = OUTPUT_DIR / "seguros_mixto.csv"
df_mix.to_csv(output_path, index=False, encoding="utf-8-sig")

print("✅ Dataset mixto generado correctamente")
print(f"📁 Archivo guardado en: {output_path}")

display(df_mix.head())
# Out:
# ✅ Dataset mixto generado correctamente
# 📁 Archivo guardado en: data\seguros_mixto.csv
#    12. ¿Ha solicitado información sobre pólizas anteriormente?  1. Edad:  \
# 0                                                  0                29.0
# 1                                                  0                44.0
# 2                                                  0                23.0
# 3                                                  2                68.0
# 4                                                  2                43.0
#
#    6. Tipo de vehículo que posee:  5. ¿Qué tan fácil fue contactarnos?  \
# 0                               1                                    3
# 1                               0                                    4
# 2                               2                                    3
# 3                               0                                    4
# 4                               0                                    3
#
#    9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Abastecimiento de combustible  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Robos al paso  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    4. ¿Cómo nos conoció?  7. Uso principal del vehículo  \
# 0                      2                              6
# 1                      2                              6
# 2                      3                              6
# 3                      3                              6
# 4                      2                              6
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Aún no cuento con un auto  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No era el momento adecuado  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  0
#
#    ...  8. ¿Con qué frecuencia utiliza su vehículo?  \
# 0  ...                                            0
# 1  ...                                            3
# 2  ...                                            4
# 3  ...                                            3
# 4  ...                                            4
#
#    9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Taller móvil  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No entendí bien las condiciones  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    11. ¿Cuál es el principal motivo por el que contrataría un seguro?  \
# 0                                                  3
# 1                                                  3
# 2                                                  7
# 3                                                  3
# 4                                                  3
#
#    9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Robo total del vehículo  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Precio elevado  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    3. Ocupación principal:  \
# 0                        3
# 1                        0
# 2                        1
# 3                        2
# 4                        3
#
#    14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Poco uso vehículo  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Daños a terceros  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    13. ¿Terminó comprando una póliza con nosotros?
# 0                                                3
# 1                                                0
# 2                                                1
# 3                                                1
# 4                                                1
#
# [5 rows x 30 columns]

# %% [markdown]
# # PROBLEMA DE CLASIFICACIÓN SUPERVISADA
# ## TARGET - VARIABLE :
# “¿Terminó comprando una póliza con nosotros?” (codificada como 0 = No compra, 1 = Sí compra)
#
#
# **Modelos predictivos supervisados que podemos trabajar:**
#
# **Regresión logística**
#
# - Modelo base y muy interpretativo.
# - Nos permite estimar la probabilidad de compra en función de las variables explicativas (edad, sexo, ocupación, tipo de vehículo, motivos, etc.).
# - Ventaja: de facil explicacion en un contexto academico.
#
#
# **Árboles de decisión (Decision Tree)**
#
# - Clasifica a los clientes según reglas claras (ejemplo: edad > 30 y vehículo = nuevo → mayor probabilidad de compra).
# - Ventaja: muy visual y útil para presentaciones ejecutivas.
#
#
# **Random Forest**
#
# - Conjunto de múltiples árboles de decisión.
# - Mejora la precisión y reduce el riesgo de sobreajuste.
# - Ventaja: robusto y maneja bien variables categóricas codificadas como dummies.
#
# *¿Que es una variable dummy?*
# Una variable dummy convierte una categoría en un valor binario.
# Los hemos usado en nuestro dataset porque los modelos matemáticos y de machine learning trabajan mejor con números que con texto.

# %%
#Trabajando con Python y scikit-learn

# 1. Importar librerías
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_auc_score
import matplotlib.pyplot as plt

# %%
# 2. Cargamos el dataset
df = pd.read_csv("seguros_codificado.csv")

# %%
print(df.columns.tolist())
# Out:
# ['1. Edad:', '2. Sexo:', '3. Ocupación principal:', '4. ¿Cómo nos conoció?', '5. ¿Qué tan fácil fue contactarnos?', '6. Tipo de vehículo que posee:', '7. Uso principal del vehículo', '8. ¿Con qué frecuencia utiliza su vehículo?', '10. ¿Qué tan importante es para usted contar con un seguro actualmente?', '11. ¿Cuál es el principal motivo por el que contrataría un seguro?', '12. ¿Ha solicitado información sobre pólizas anteriormente?', '13. ¿Terminó comprando una póliza con nosotros?', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Abastecimiento de combustible', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Asistencia mecánica', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Cobertura contra desastres naturales', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Daños a terceros', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Daños propio', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - No tengo auto', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Robo total del vehículo', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Robos al paso', '9. ¿Qué cobertura le interesa más en un seguro vehicular? (Puede marcar más de una opción) - Taller móvil', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Aún no cuento con un auto', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - En general he tenido muchos problemas con aseguradoras', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Falta de confianza en la aseguradora', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Mi auto es muy antiguo y no lo aseguran', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Mi seguro vence en un mes y ahí lo adquiriría aqui', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No entendí bien las condiciones', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - No era el momento adecuado', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Poco uso vehículo', '14. ¿Cuál fue el principal motivo para no adquirir la póliza? - Precio elevado']

# %%
df["target_binaria"] = df["13. ¿Terminó comprando una póliza con nosotros?"].replace({
    3: 1,  # Sí
    1: 1,  # Interesada
    2: 0,  # No interesado
    0: 0   # Vacío
})

# Verificación rápida
print(df["target_binaria"].value_counts())
# Out:
# target_binaria
# 1    64
# 0    18
# Name: count, dtype: int64

# %%
X = df.drop(columns=["target_binaria"])
y = df["target_binaria"]

# %%
# 4. Separamos para el entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
#Entrenamiento de modelos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

log_model = LogisticRegression(max_iter=1000, random_state=42)
rf_model = RandomForestClassifier(random_state=42)

log_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print(y_test.unique())
# Out:
# [0 1]

# %% [markdown]
# # RESULTADOS DE EVALUACION DE DESEMPEÑO
#
# - Matriz de confusión → para ver aciertos y errores en clasificación.
#
# - Reporte de clasificación → precisión, recall y F1-score.
#
# - ROC-AUC → calidad del modelo en distinguir entre positivos y negativos.
#
# - Gráfico de importancia de variables → qué factores influyen más en la predicción.

# %%
#Evaluamos desempeño
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Evaluación y visualización por modelo
for model, name in [(log_model, "Logistic Regression"), (rf_model, "Random Forest")]:
    y_pred = model.predict(X_test)

    print(f"\n{name}")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("ROC-AUC:", roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))

    # Plot de matriz de confusión
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap="Blues", values_format="d")
    plt.title(f"Matriz de Confusión - {name}")
    plt.show()
# Out:
# Logistic Regression
# [[ 1  4]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29         5
#            1       0.83      0.95      0.88        20
#
#     accuracy                           0.80        25
#    macro avg       0.66      0.57      0.58        25
# weighted avg       0.76      0.80      0.76        25
#
# ROC-AUC: 0.86
# Random Forest
# [[ 3  2]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       0.91      1.00      0.95        20
#
#     accuracy                           0.92        25
#    macro avg       0.95      0.80      0.85        25
# weighted avg       0.93      0.92      0.91        25
#
# ROC-AUC: 0.9800000000000001

# %%
#Visualización e importancia - Random Forest

import pandas as pd
import matplotlib.pyplot as plt

importances = pd.Series(rf_model.feature_importances_, index=X.columns)
importances.sort_values().plot(kind="barh", figsize=(8,6))
plt.title("Importancia de variables")
plt.show()

# %% [markdown]
# #Comparación grafica de las curvas ROC en ambos modelos
# - Una curva ROC para cada modelo en el mismo gráfico.
#
# - El AUC de cada modelo mostrado en la leyenda.
#
# - Una línea diagonal de referencia (clasificación aleatoria).

# %%
#========================================================
#Comparación grafica de las curvas ROC en ambos modelos
#========================================================

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Probabilidades de cada modelo
log_probs = log_model.predict_proba(X_test)[:, 1]
rf_probs = rf_model.predict_proba(X_test)[:, 1]

# Curvas ROC
fpr_log, tpr_log, _ = roc_curve(y_test, log_probs)
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_probs)

# AUC
auc_log = roc_auc_score(y_test, log_probs)
auc_rf = roc_auc_score(y_test, rf_probs)

# Gráfico comparativo
plt.figure(figsize=(8, 6))
plt.plot(fpr_log, tpr_log, label=f'Regresión Logística (AUC = {auc_log:.2f})', linewidth=2)
plt.plot(fpr_rf, tpr_rf, label=f'Random Forest (AUC = {auc_rf:.2f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--', label='Aleatorio')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Comparación de Curvas ROC')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# # CONCLUSIONES Y RECOMENDACIONES
#
# **Conclusiones**
# - El modelo nos permite segmentar perfiles con mayor probabilidad de compra.
#
# - Se pueden focalizar campañas comerciales en clientes interesados o con características similares a los compradores.
#
# - La documentación es reproducible asegura que el proceso pueda ser auditado y replicado.
#
# - Haber aplicado las métricas (ROC-AUC, F1, matriz de confusión) respalda la confiabilidad del modelo.
#
#
# **Recomendaciones estratégicas**
#
# - Aplicar el modelo como herramienta de apoyo en las campañas de seguros vehiculares.
#
# - Priorizar las variables más influyentes en el despliegue comercial.
#
# - Continuar alimentando el dataset con nuevas encuestas o datos transaccionales, previamente validando las encuestas para medir su confiabilidad.
#
# - Mantener dashboards interactivos para el monitoreo de resultados en tiempo real.

# %% [markdown]
# # SIMULACION CON CLIENTES NUEVOS

# %%
cliente_prueba = X_test.iloc[[3]]
pred = model.predict(cliente_prueba)[0]
prob = model.predict_proba(cliente_prueba)[0][1]

print("¿Compra seguro?:", "Sí" if pred==1 else "No")
print(f"Probabilidad de compra: {prob:.2f}")
# Out:
# ¿Compra seguro?: Sí
# Probabilidad de compra: 0.98
